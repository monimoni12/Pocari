# %% [markdown]
# <a href="https://colab.research.google.com/github/sooonsyk/Pocari/blob/main/classification/yolo_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16605, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 16605 (delta 50), reused 97 (delta 48), pack-reused 16459
# Receiving objects: 100% (16605/16605), 15.32 MiB | 18.16 MiB/s, done.
# Resolving deltas: 100% (11349/11349), done.

# %%
 # !pip install -r /content/yolov5/requirements.txt
# Out:
# Collecting gitpython>=3.1.30 (from -r /content/yolov5/requirements.txt (line 5))
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 7)) (1.25.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 8)) (4.8.0.76)
# Collecting pillow>=10.3.0 (from -r /content/yolov5/requirements.txt (line 9))
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 11)) (6.0.1)
# Collecting requests>=2.32.0 (from -r /content/yolov5/requirements.txt (line 12))
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 13)) (1.11.4)
# Collecting thop>=0.1.1 (from -r /content/yolov5/requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 15)) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 16)) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 17)) (4.66.4)
# Collecting ultralytics>=8.0.232 (from -r /content/yolov5/requirements.txt (line 18))
#   Downloading ultralytics-8.2.29-py3-none-any.whl (780 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.5/780.5 kB 31.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 27)) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 28)) (0.13.1)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 42)) (67.7.2)
# Requirement already satisfied: wheel>=0.38.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/yolov5/requirements.txt (line 50)) (0.43.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r /content/yolov5/requirements.txt (line 5))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0->-r /content/yolov5/requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0->-r /content/yolov5/requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0->-r /content/yolov5/requirements.txt (line 12)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0->-r /content/yolov5/requirements.txt (line 12)) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (4.12.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15))
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 63.9 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.232->-r /content/yolov5/requirements.txt (line 18)) (9.0.0)
# Collecting ultralytics-thop>=0.2.5 (from ultralytics>=8.0.232->-r /content/yolov5/requirements.txt (line 18))
#   Downloading ultralytics_thop-0.2.7-py3-none-any.whl (25 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r /content/yolov5/requirements.txt (line 27)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r /content/yolov5/requirements.txt (line 27)) (2024.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r /content/yolov5/requirements.txt (line 5))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (1.3.0)
# Installing collected packages: smmap, requests, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, gitdb, nvidia-cusolver-cu12, gitpython, ultralytics-thop, thop, ultralytics
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.3.0 which is incompatible.
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 pillow-10.3.0 requests-2.32.3 smmap-5.0.1 thop-0.1.1.post2209072238 ultralytics-8.2.29 ultralytics-thop-0.2.7

# %%
# %cat /content/yolov5/data/classification_data.yaml
# Out:
# train: /content/drive/MyDrive/YOLO_classification_0601/images/train  # train images (relative to 'path') 4 images
# val: /content/drive/MyDrive/YOLO_classification_0601/images/val     # val images (relative to 'path') 4 images
# test: /content/drive/MyDrive/YOLO_classification_0601/images/test   # test images (optional)
#
# # Classes
#
# nc : 5
# names: ['blood', 'diarrhea', 'green', 'normal', 'white']

# %%
# !python /content/yolov5/train.py --epochs 50 --data /content/yolov5/data/classification_data.yaml --name yolo_classification
# Out:
# 2024-06-09 12:14:53.394072: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 12:14:53.394124: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 12:14:53.395534: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5/yolov5s.pt, cfg=, data=/content/yolov5/data/classification_data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=yolo_classification, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-321-g3742ab49 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 20.0MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5/yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 192MB/s]
#
# Overriding model.yaml nc=80 with nc=5
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     26970  models.yolo.Detect                      [5, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7033114 parameters, 7033114 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5/yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/MyDrive/YOLO_classification_0601/labels/train.cache... 28 images, 0 backgrounds, 0 corrupt: 100% 28/28 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/YOLO_classification_0601/labels/val.cache... 11 images, 0 backgrounds, 0 corrupt: 100% 11/11 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/YOLO_classification_0601/images/val/normal_1.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/drive/MyDrive/YOLO_classification_0601/images/val/normal_2.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/drive/MyDrive/YOLO_classification_0601/images/val/normal_4.jpg: corrupt JPEG restored and saved
#
# AutoAnchor: 2.86 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/yolo_classification/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to yolov5/runs/train/yolo_classification
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49      3.66G     0.1107    0.03339    0.05113         31        640: 100% 2/2 [00:14<00:00,  7.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.050s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:04<00:00,  4.08s/it]
#                    all         11         11          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49      3.66G     0.1118    0.03265    0.06538         32        640: 100% 2/2 [00:00<00:00,  2.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.050s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.60s/it]
#                    all         11         11          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/49      3.66G     0.1092    0.03241    0.05915         27        640: 100% 2/2 [00:00<00:00,  2.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.050s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.35s/it]
#                    all         11         11          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/49      3.66G     0.1087    0.03054    0.05191         30        640: 100% 2/2 [00:00<00:00,  2.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.050s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all         11         11          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/49      3.66G    0.08849    0.03394    0.04358         35        640: 100% 2/2 [00:00<00:00,  3.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.050s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all         11         11          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/49      3.66G     0.1028    0.03039    0.06213         30        640: 100% 2/2 [00:00<00:00,  3.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.050s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.33s/it]
#                    all         11         11          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/49      3.66G    0.09508    0.03167    0.04883         30        640: 100% 2/2 [00:00<00:00,  2.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.050s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all         11         11          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/49      3.66G    0.09671    0.03373       0.05         42        640: 100% 2/2 [00:01<00:00,  1.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.08s/it]
#                    all         11         11          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/49      3.66G     0.1019    0.03239    0.04955         34        640: 100% 2/2 [00:00<00:00,  2.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all         11         11     0.0011       0.24    0.00243   0.000298
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/49      3.66G    0.07772      0.033    0.04265         29        640: 100% 2/2 [00:00<00:00,  3.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.86it/s]
#                    all         11         11   0.000867       0.24    0.00259   0.000465
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/49      3.66G    0.08678    0.03032    0.04537         32        640: 100% 2/2 [00:00<00:00,  3.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.47it/s]
#                    all         11         11    0.00065       0.14   0.000851   0.000256
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/49      3.66G    0.08742    0.03253    0.04059         38        640: 100% 2/2 [00:00<00:00,  3.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.00it/s]
#                    all
00:00,  3.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  6.71it/s]
#                    all         11         11      0.841       0.08      0.317      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/49      3.66G    0.06019    0.02742    0.03124         32        640: 100% 2/2 [00:00<00:00,  4.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.41it/s]
#                    all         11         11      0.841       0.08      0.317      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/49      3.66G    0.05369    0.02662    0.02662         24        640: 100% 2/2 [00:00<00:00,  3.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.13it/s]
#                    all         11         11      0.836       0.08      0.306      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/49      3.66G    0.06148    0.03049     0.0363         36        640: 100% 2/2 [00:00<00:00,  2.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.98it/s]
#                    all         11         11      0.831       0.08      0.317      0.153
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/49      3.66G    0.05084    0.02659    0.02947         26        640: 100% 2/2 [00:01<00:00,  1.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.16it/s]
#                    all         11         11      0.831       0.08      0.317      0.153
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/49      3.66G    0.06579    0.02841    0.02878         26        640: 100% 2/2 [00:01<00:00,  1.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.04it/s]
#                    all         11         11      0.836       0.12      0.325       0.18
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/49      3.66G     0.0645    0.02684    0.02773         33        640: 100% 2/2 [00:00<00:00,  3.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.81it/s]
#                    all         11         11      0.836       0.12      0.325       0.18
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/49      3.66G    0.06229    0.02749    0.02777         30        640: 100% 2/2 [00:00<00:00,  2.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.71it/s]
#                    all         11         11       0.88       0.08      0.261      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/49      3.66G    0.06148    0.03088    0.03305         33        640: 100% 2/2 [00:00<00:00,  2.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.66it/s]
#                    all         11         11       0.88       0.08      0.261      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/49      3.66G     0.0508    0.02613    0.02513         32        640: 100% 2/2 [00:01<00:00,  1.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.65it/s]
#                    all         11         11      0.962       0.08      0.197     0.0698
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/49      3.66G    0.05448    0.02673    0.05505         31        640: 100% 2/2 [00:00<00:00,  3.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.30it/s]
#                    all         11         11      0.962       0.08      0.197     0.0698
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/49      3.66G    0.06282    0.02779    0.04212         31        640: 100% 2/2 [00:01<00:00,  1.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.20it/s]
#                    all         11         11      0.949       0.08      0.194     0.0728
#
# 50 epochs completed in 0.055 hours.
# Optimizer stripped from yolov5/runs/train/yolo_classification/weights/last.pt, 14.5MB
# Optimizer stripped from yolov5/runs/train/yolo_classification/weights/best.pt, 14.5MB
#
# Validating yolov5/runs/train/yolo_classification/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.71it/s]
#                    all         11         11      0.836       0.12      0.326      0.182
#                  blood         11          1          1          0      0.199      0.179
#               diarrhea         11          1          1          0      0.995      0.597
#                  green         11          2          1          0      0.021    0.00857
#                 normal         11          5      0.182        0.6      0.385      0.111
#                  white         11          2          1          0     0.0282     0.0163
# Results saved to yolov5/runs/train/yolo_classification

# %%
# !python /content/yolov5/detect.py --source /content/drive/MyDrive/YOLO_classification_0601/images/test --weights /content/yolov5/runs/train/yolo_classification/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/yolo_classification/weights/best.pt'], source=/content/drive/MyDrive/YOLO_classification_0601/images/test, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-321-g3742ab49 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/drive/MyDrive/YOLO_classification_0601/images/test/blood_1.png: 640x480 (no detections), 50.6ms
# image 2/8 /content/drive/MyDrive/YOLO_classification_0601/images/test/diarrhea_3.png: 448x640 2 normals, 53.8ms
# image 3/8 /content/drive/MyDrive/YOLO_classification_0601/images/test/green_5.png: 640x512 (no detections), 50.8ms
# image 4/8 /content/drive/MyDrive/YOLO_classification_0601/images/test/normal_7.png: 480x640 (no detections), 59.2ms
# image 5/8 /content/drive/MyDrive/YOLO_classification_0601/images/test/normal_8.png: 640x480 (no detections), 8.7ms
# image 6/8 /content/drive/MyDrive/YOLO_classification_0601/images/test/normal_9.png: 480x640 (no detections), 9.0ms
# image 7/8 /content/drive/MyDrive/YOLO_classification_0601/images/test/white_10.png: 640x480 (no detections), 11.2ms
# image 8/8 /content/drive/MyDrive/YOLO_classification_0601/images/test/white_9.png: 480x640 (no detections), 9.0ms
# Speed: 0.7ms pre-process, 31.5ms inference, 71.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp

# %%
from skimage import io
import matplotlib.pyplot as plt

img_dir = '/content/yolov5/runs/detect/exp/diarrhea_3.png'
image = io.imread(img_dir)
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.show()
